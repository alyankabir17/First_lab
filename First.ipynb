# %%
import keyword as kw

# %%
1age=10
# Out:
#   Cell In[5], line 1
#     1age=10
#     ^
# SyntaxError: invalid decimal literal

# %%
print(kw.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(len(kw.kwlist))
# Out:
# 35

# %%
a=10
print("value of a is "+" "+ str(a))
# Out:
# value of a is  10

# %%
x=input("enter the number")
print(x)
# Out:
# 5

# %%
a=10
b=20
print("value of a is {} and b is {} ".format(a,b))
# Out:
# value of a is 10 and b is 20

# %%
print("value of a is {1} and value of b is {0} ".format(a,b))
# Out:
# value of a is 20 and value of b is 10

# %%
x = float(input("Enter first number"))
y = float(input("Enter second number"))
print("Sum of first and second number is",x + y)
print("Sub of first and second number is",x - y)
print("MUltiply of first and second number is",x * y)
print("Division of first and second number is",x / y)
# Out:
# Sum of first and second number is 8.0
# Sub of first and second number is 0.0
# MUltiply of first and second number is 16.0
# Division of first and second number is 1.0

# %%
print("Hello,{name},{greetings}".format(name="Alex",greetings="Good Luck"))
# Out:
# Hello,Alex,Good Luck

# %%
print("The story of  {0},{1},{other}".format("vinay","sir",other="kgcoding"))
# Out:
# The story of  vinay,sir,kgcoding
